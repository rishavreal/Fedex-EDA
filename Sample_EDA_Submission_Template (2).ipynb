# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/rishavreal

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Fedex logistics manages a complete global supply chain , dealing with shipments across various regions , countries and industries. This dataset provides an in-depth look ata their logistics processes, capturing important information on purchase order(POs), shipment methods, vendor agreements(INCO terms), delivery schedules and product-specific details such as item description and dosage forms. Effective management of these processes ensures timely delivery, minimizes freight costs, and improves customer satisfaction.
# Here the Business objective is to optimize logistics operations, identify bottlenecks or delays and ensure cost-effectiveness.Fedex logistics aims to streamline supply chain operations , improving delivery timelines and reducing costs for both the company and its customers.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv("SCMS_Delivery_History_Dataset.csv")
df.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %% [markdown]
# ### Dataset First View

# %%
print(df)
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
rows, columns=df.shape
print(f"Rows: {rows}, Columns: {columns}")
# Out:
# Rows: 10324, Columns: 33

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Project Code, PQ #, PO / SO #, ASN/DN #, Country, Managed By, Fulfill Via, Vendor INCO Term, Shipment Mode, PQ First Sent to Client Date, PO Sent to Vendor Date, Scheduled Delivery Date, Delivered to Client Date, Delivery Recorded Date, Product Group, Sub Classification, Vendor, Item Description, Molecule/Test Type, Brand, Dosage, Dosage Form, Unit of Measure (Per Pack), Line Item Quantity, Line Item Value, Pack Price, Unit Price, Manufacturing Site, First Line Designation, Weight (Kilograms), Freight Cost (USD), Line Item Insurance (USD)]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %%
"""Dosage is having many null values i.e.,1736 followed by shipment
 mode columns with 360 null values and column life item insurance having 287 null values"""

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   77.990895        18332.534870
# std    31944.332496                   76.579764        40035.302961
# min        1.000000                    1.000000            1.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# max    86823.000000                 1000.000000       619999.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     1.032400e+04  10324.000000  10324.000000               10037.000000
# mean      1.576506e+05     21.910241      0.611701                 240.117626
# std       3.452921e+05     45.609223      3.275808                 500.190568
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# """ the dataset contains a total of 33 columns, there are no duplicate values present but there are null values present in 3 columns namely - dosage, life item insurance and shipment mode"""

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
print("Unique values for each variable:")
for x in df.columns:
    unique= df[x].unique()
    print(f'{x}: {unique} ')
# Out:
# Unique values for each variable:
# ID: [    1     3     4 ... 86821 86822 86823]
# Project Code: ['100-CI-T01' '108-VN-T01' '112-NG-T01' '110-ZM-T01' '109-TZ-T01'
#  '102-NG-T01' '107-RW-T01' '106-HT-T01' '113-ZW-T01' '104-CI-T01'
#  '100-HT-T01' '117-ET-T01' '116-ZA-T01' '123-NG-T01' '125-HT-T01'
#  '102-GY-T01' '119-NA-T01' '131-NG-T01' '102-BW-T01' '111-MZ-T01'
#  '144-BW-T01' '102-KE-T01' '133-NG-T01' '100-KZ-T01' '141-NA-T01'
#  '114-UG-T01' '105-GY-T01' '139-NA-T01' '129-KG-T01' '100-SN-T01'
#  '128-BJ-T01' '102-LS-T01' '130-NG-T01' '100-BW-T01' '100-ZW-T01'
#  '100-PK-T01' '126-NG-T01' '151-NG-T01' '100-SZ-T01' '100-GH-T01'
#  '120-AO-T01' '132-NG-T01' '153-NG-T01' '100-LB-T01' '151-NG-T30'
#  '127-KE-T01' '510-KE-T01' '100-SL-T01' '136-RW-T01' '102-KE-T30'
#  '108-VN-T30' '110-ZM-T30' '106-HT-T30' '105-SS-T30' '111-MZ-T30'
#  '102-BI-T30' '122-HT-T30' '161-ZA-T30' '116-ZA-T30' '133-NG-T30'
#  '103-DO-T30' '104-CI-T30' '107-RW-T30' '103-MW-T30' '101-CD-T30'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#removing duplicate value
df.drop_duplicates(inplace=True)

# %%
df.fillna(df.mean(numeric_only=True), inplace=True) #filling missing numerical values with mean
df.fillna(df.mode().iloc[0],inplace=True) # filling categorical missing values with mode

# %%
df.isnull().sum()
# Out:
# ID                              0
# Project Code                    0
# PQ #                            0
# PO / SO #                       0
# ASN/DN #                        0
# Country                         0
# Managed By                      0
# Fulfill Via                     0
# Vendor INCO Term                0
# Shipment Mode                   0
# PQ First Sent to Client Date    0
# PO Sent to Vendor Date          0
# Scheduled Delivery Date         0
# Delivered to Client Date        0
# Delivery Recorded Date          0
# Product Group                   0
# Sub Classification              0
# Vendor                          0
# Item Description                0
# Molecule/Test Type              0
# Brand                           0
# Dosage                          0
# Dosage Form                     0
# Unit of Measure (Per Pack)      0
# Line Item Quantity              0
# Line Item Value                 0
# Pack Price                      0
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# - Removed duplicates if any
# - Handled missing values by putting mean for numerical values and mode for categorical values.
# Insights :
# on comparing the columns shipment mode and delivery recorded date I can analyse that how shipment mode effects the delivery time further on compairing columns like freight, country and shipment mode i can find which country is having higher and low freight cost as per shipment mode which will be helpful on selecting cost friendly and best shipment mode from different countries.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
# freight cost by county
plt.figure(figsize=(12,8))
plt.bar(df["Country"], df["Freight Cost (USD)"])
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is easy to understand and clearly shows the relation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# kazakhstan, kyrgyzstan and Burkina Faso are the three countries with don't have any freight cost then Lebanon and lesotho are the 2nd and 3rd top countries which have very less freight cost as compared to other coutries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %%
Yes this insight will help the company to choose which coutry has very hight freight cost and which have less compared to other countries and accordingly choose from which country they can have more transactions which reducing its freight cost.

# %% [markdown]
# #### Chart - 2

# %%
plt.figure(figsize=(12,6))
df.groupby('Shipment Mode')['Product Group'].count().plot()
plt.xlabel('Shipment Mode')
plt.ylabel('Product Group')
plt.title('Different Product Group and their shipment mode as per delivery recorded date')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have choosed the line chart because it clearly shows the relation between product group and shipment mode

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# MOst of the product groups where shipped using AIR medium then comes through road transport i.e,. Truck and very few product groups where sent through Ocean.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %%
Yes it shows the company through which medium most of their logistics are send , which will further help them optimize their shipment methods.

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Product Group',data=df, hue= 'Sub Classification')
plt.xlabel('Product Group')
plt.ylabel('Line Item Quantity')
plt.title('Product Group vs Line Item Quantity as per sub classification')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# BeCause it clearly shows the Sub classification of different product group as per their Line item quantity

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Adults from the ARV product group have ordered the most Line items then comes the Pediatric patients from the same ARV group who order the most quantity of Line items, people from HIV test-Ancillary from the HRDT group have ordered the least amount of Line items

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes this insight will help business find their target customer according to Different product groups and further optimize logitics accordingly by focusing more on those products those products who demand is more and further maintain the stock of those products.

# %% [markdown]
# #### Chart - 4

# %%
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
for x in df['Fulfill Via'].unique():
    df1= df[df['Fulfill Via']==x]
    plt.plot(df1.groupby('Country')['Fulfill Via'].count(), label= x)
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.ylabel('Methods')
plt.title('Different methods of shipment vs country')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart clearly shows the different shipment methods used by different countries and indicates whether the product is from direct drop or from RDC

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the less developed countries like congo , Nigeria , uganda etc.,  have shipments from the RDC while south africa , vietnam have most of the shipment from direct drop.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# company should use different methods of shipment according to the physical features of the country and futher decide which method suits more according to the country type and access to the country's geographical features

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12,6))
sns.countplot(x='Manufacturing Site', data=df, hue='Brand')
plt.xlabel('Manufacturing Site')
plt.ylabel('Brands')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it clearly shows the different types of Brands and their manufacturing sites

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the brands have their manufacturing sites located in india  in which Nashik is top and comes Bangalore

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes it will help the company know from where most of their manufacturing shipments comes and further help to provide more logitics support to those manufacturing sites ensuring timely delivery of manufactured goods to different brands.

# %% [markdown]
# #### Chart - 6

# %%
sns.relplot(x='Country', y="Sub Classification", data= df, kind="scatter")
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot clearly depicts the different countries and their sub classification

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the country are having adults and Hiv test  and very few coutries are having ACT.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight will help the company focus more on sub-classification categories in which there are high number of people from different countries also will help it to optimize its processes according to the priority of different countries according to the sub-classification.

# %% [markdown]
# #### Chart - 7

# %%
sns.countplot(x="Sub Classification", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar graph cleary shows the counts of different sub classification

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the people are from the adult group having more than 6000+ count , then comes people with pediatric needs having approx. 2000 counts and then comes Number of HIV test which is the third top sub classification as per the number of counts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes this will help business optimize its logistics as per different sub-classifications.

# %% [markdown]
# #### Chart - 8

# %%
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
sns.countplot(x="Product Group", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# clearly depicts the count of different product groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the product groups are from ARV and then 2nd top product groups are from HRDT.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The count of products groups from ACT , MRDT and ANTM are negligible so company should focus more on products form ARV and HRDT which help reduce its operational cost and optimize its processes.

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(18,9))
sns.countplot(x= "Molecule/Test Type",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# clearly shows the count of different Molecule/Test type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# most of the products are from molecule/test type - "Efavirenz" then comes the HIV test and the third most count are from molecule Lamivudine/Nevirapine/zidovudine

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight will help company categorize its logitics according to molecule/test type and further optimize its processes.

# %% [markdown]
# #### Chart - 10

# %%
sns.relplot(x="Scheduled Delivery Date", y="Delivered to Client Date",data=df, kind="scatter", col="Shipment Mode")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot clearly shows the scheduled delivery date according to different shipment modes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# most of the scheduled delivery dates were made from shipment method(Air) then comes Truck and then ocean.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes this insight will help business optimize its task by giving more focus on shipments made through Air and through truck and also help the company bring schemes and offers to increase the number of shipment made through oceans and Air charter.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
